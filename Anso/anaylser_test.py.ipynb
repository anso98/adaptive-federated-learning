# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

# %%
weights_global = np.array([3.90420672e-04,  7.85652814e-04,  1.13941092e-03,  1.36541801e-03,
  1.51223724e-03,  1.39838617e-03,  1.30664365e-03,  8.56909161e-04,
  7.32229226e-04,  6.34644751e-04,  5.08479087e-04,  3.57628903e-04,
  2.79351381e-04,  1.73683630e-04,  1.00229823e-04,  3.75627808e-05])

# %%
weights_node1 = np.array([0,  7.85652814e-04,  1.13941092e-03,  1.36541801e-03,
  1.51223724e-03,  1.39838617e-03,  1.30664365e-03,  8.56909161e-04,
  7.32229226e-04,  6.34644751e-04,  5.08479087e-04,  3.57628903e-04,
  2.79351381e-04,  1.73683630e-04,  1.00229823e-04,  3.75627808e-05])

# %%
weights_node2 = np.array([3.90420672e-04,  7.85652814e-04,  1.13941092e-03,  1.36541801e-03,
  1.51223724e-03,  1.39838617e-03,  1.30664365e-03,  8.56909161e-04,
  7.32229226e-04,  6.34644751e-04,  5.08479087e-04,  3.57628903e-04,
  2.79351381e-04,  1.73683630e-04,  1.00229823e-04,  3.75627808e-05])

# %%
weights_node3 = np.array([3.90420672e-04,  7.85652814e-04,  1.13941092e-03,  1.36541801e-03,
  1.51223724e-03,  1.39838617e-03,  1.30664365e-03,  8.56909161e-04,
  7.32229226e-04,  6.34644751e-04,  5.08479087e-04,  3.57628903e-04,
  2.79351381e-04,  1.73683630e-04,  1.00229823e-04,  3.75627808e-05])

# %%
weights_node4 = np.array([3.90420672e-04,  7.85652814e-04,  1.13941092e-03,  1.36541801e-03,
  1.51223724e-03,  1.39838617e-03,  1.30664365e-03,  8.56909161e-04,
  7.32229226e-04,  6.34644751e-04,  5.08479087e-04,  3.57628903e-04,
  2.79351381e-04,  1.73683630e-04,  1.00229823e-04,  3.75627808e-05])

# %%
weights_node5 = np.array([3.90420672e-04,  7.85652814e-04,  1.13941092e-03,  1.36541801e-03,
  1.51223724e-03,  1.39838617e-03,  1.30664365e-03,  8.56909161e-04,
  7.32229226e-04,  6.34644751e-04,  5.08479087e-04,  3.57628903e-04,
  2.79351381e-04,  1.73683630e-04,  1.00229823e-04,  3.75627808e-05])

# %%
#Panda array
pandaVersion_weights = pd.Series(weights_global)

# %%
print(weights_global.mean())
print(weights_global.std())
print(weights_global.max())
# Out:
# 0.0007236805136749999
# 0.00047970602570790503
# 0.00151223724

# %%
plt.plot(weights_global)
plt.plot(weights_node1)
plt.title("Average weight per iteration")
plt.xlabel("Update Round")
plt.ylabel("Average Weight")
plt.grid(axis="y", linewidth=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(weights_global)
plt.title("Average weight per iteration")
plt.xlabel("Update Round")
plt.ylabel("Average Weight")
plt.grid(axis="y", linewidth=0.5)

# %%
sns.scatterplot(data = weights_global)
# Out:
# <AxesSubplot:>

# %%
#note: what do I want to do:
# average accross all weights for each node
# take this average and save it in an array for each node for each iteration
# afterwards plot the 5 averages and the global value over all iteration to see where they are to show how they are distributed

# %%
mean_weights = np.array()
#iterate through and check what there is!

# %%
# afterwards: take the average from all arrays for each iteration 
# plot the std for each of those values in each iteration from the mean

# %%
no1 = np.array([0, 2])
no2 = np.array([2, 4])
no3 = np.array([4, 6])

# %%
np.empty((5, 2, 10))
#for i in range(0, 5):
    #np.append(4)
# Out:
# array([[[2.31584178e+077, 2.31584178e+077, 3.06320700e-322,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          2.49580160e-314, 2.49580160e-314, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000]],
#
#        [[0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000],
#         [0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000]],
#
#        [[0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#          0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
# ...

# %%
weights = np.zeros((2))
weights
# Out:
# array([0., 0.])

# %%
weights[1] = 10
weights
# Out:
# array([None, 10], dtype=object)

# %%
# Out:
# 100

# %%
array = [1, 2, 3, 4, 5, 6]

# %%
np_array = np.empty((2, 3, 6))

# %%
np_array
# Out:
# array([[[ 2.31584178e+077, -1.49457366e-154,  8.89318163e-323,
#           1.87744945e-321,  4.47919915e-320,  1.91203405e-321],
#         [ 4.47129409e-320,  1.91203405e-321,  4.44214422e-320,
#           1.91203405e-321,  4.41151215e-320,  1.51678153e-321],
#         [ 4.41151215e-320,  1.15117295e-321,  4.41151215e-320,
#           0.00000000e+000,  4.37544536e-320,  0.00000000e+000]],
#
#        [[ 4.37544536e-320,  2.21341409e-321,  4.41151215e-320,
#           2.21341409e-321,  4.41151215e-320,  1.83792420e-321],
#         [ 4.42238160e-320,  2.02566915e-321,  4.45647213e-320,
#           2.21341409e-321,  4.48117541e-320,  2.21341409e-321],
#         [ 4.48463387e-320,  2.21341409e-321,  4.49352705e-320,
#           2.22823606e-321,  4.49846771e-320,  2.50320809e-308]]])

# %%
np_array[1][2] = array

# %%
np_array
# Out:
# array([[[1.0000e+000, 2.0000e+000, 3.0000e+000, 4.0000e+000,
#          5.0000e+000, 6.0000e+000],
#         [4.4713e-320, 1.9120e-321, 4.4421e-320, 1.9120e-321,
#          4.4115e-320, 1.5168e-321],
#         [1.0000e+000, 2.0000e+000, 3.0000e+000, 4.0000e+000,
#          5.0000e+000, 6.0000e+000]],
#
#        [[4.3754e-320, 2.2134e-321, 4.4115e-320, 2.2134e-321,
#          4.4115e-320, 1.8379e-321],
#         [4.4224e-320, 2.0257e-321, 4.4565e-320, 2.2134e-321,
#          4.4812e-320, 2.2134e-321],
#         [1.0000e+000, 2.0000e+000, 3.0000e+000, 4.0000e+000,
#          5.0000e+000, 6.0000e+000]]])

# %%
number_of_nodes = 5
for i in range(0, number_of_nodes):
    print("Hi")
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi

# %%
average = (np.array(no1) + np.array(no2) + np.array(no3))/3
print(average)
# Out:
# [2. 4.]

# %%
average[0]
# Out:
# 2.0

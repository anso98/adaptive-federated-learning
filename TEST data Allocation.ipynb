# %%
#TEST data Allocation

# %%
ls
# Out:
# Anso/                        config.py
# Check Formula.ipynb          configAH.py
# LICENSE                      control_algorithm/
# README.md                    data_reader/
# TEST data Allocation.ipynb   datasets/
# __pycache__/                 models/
# all_cases_analyser.py        plot_multi_run.py
# analyser.py                  requirements.txt
# analysis                     results/
# analysis_results/            server.py
# centralized.py               serverAH.py
# check_FL_Algorithm.py.ipynb  statistic/
# client.py                    util/
# clientAH.py

# %%
pwd
# Out:
# '/Users/Anso/Code/Imperial_College/IndividualProject/adaptive-federated-learning'

# %%
from models.get_model import get_model
from configAH import *
from util.utils import get_indices_each_node_case
from data_reader.data_reader import get_data

# %%
dataset = "MNIST_ORIG_EVEN_ODD"
total_data = 30000  # 60000  #Value for stochastic gradient descent
dataset_file_path = "/Users/Anso/Code/Imperial_College/IndividualProject/adaptive-federated-learning/datasets"

# %%
train_image, train_label, test_image, test_label, train_label_orig = get_data(dataset, total_data, dataset_file_path)

# %%
len(train_label_orig)
# Out:
# 30000

# %%
n_nodes = 5
maxCase = 5
label_list = train_label_orig

# %%
indices_each_node_case = get_indices_each_node_case(n_nodes, maxCase, label_list)
# Out:
# 5
# Num_labels 10
# min Label 0
# max Label 9
# len Label list 30000
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# CHECK POINT
# ...

# %%
len(indices_each_node_case)
# Out:
# 5

# %%
print(len(indices_each_node_case[0][0]))
print(len(indices_each_node_case[0][1]))
print(len(indices_each_node_case[0][2]))
print(len(indices_each_node_case[0][3]))
print(len(indices_each_node_case[0][4]))
# Out:
# 6000
# 6000
# 6000
# 6000
# 6000

# %%
print(len(indices_each_node_case[1][0]))
print(len(indices_each_node_case[1][1]))
print(len(indices_each_node_case[1][2]))
print(len(indices_each_node_case[1][3]))
print(len(indices_each_node_case[1][4]))


case1_node1_indicies = indices_each_node_case[1][0]
case1_node2_indicies = indices_each_node_case[1][1]
case1_node3_indicies = indices_each_node_case[1][2]
case1_node4_indicies = indices_each_node_case[1][3]
case1_node5_indicies = indices_each_node_case[1][4]
# Out:
# 5670
# 6398
# 6055
# 5948
# 5929

# %%
for element in case1_node5_indicies:
    print(train_label_orig[element])
# Out:
# 4
# 9
# 4
# 9
# 4
# 9
# 4
# 9
# 9
# 9
# 9
# 4
# 9
# 9
# 4
# 4
# 4
# 4
# 9
# 9
# 4
# 4
# 9
# 4
# 9
# 4
# 4
# 9
# 4
# 4
# 4
# 9
# 9
# 9
# 4
# 4
# 4
# 9
# 9
# 9
# 9
# 9
# 4
# 9
# 4
# 4
# 9
# 9
# 4
# 9
# 4
# 9
# 9
# 4
# 4
# 4
# 9
# 9
# 9
# 4
# 4
# 4
# 4
# 9
# 9
# 4
# 9
# 9
# 4
# 9
# 4
# 4
# 4
# 9
# 9
# 9
# 4
# 9
# 4
# 9
# 4
# 4
# 4
# 9
# 4
# 4
# 9
# 9
# 4
# 9
# 4
# 4
# 4
# 9
# 9
# 9
# 9
# 9
# 4
# 9
# 4
# 9
# 4
# 9
# 4
# 9
# 9
# 9
# 9
# 9
# 9
# 4
# 4
# 9
# 4
# 9
# 4
# 4
# 9
# 9
# 4
# 9
# 4
# 9
# 9
# 9
# 4
# 4
# 4
# 9
# 9
# 9
# 9
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 9
# 4
# 4
# 4
# 9
# 4
# 9
# 4
# 4
# 9
# 4
# 9
# 4
# 9
# 4
# 4
# 4
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 4
# 9
# 4
# 9
# 9
# 9
# 9
# 9
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 4
# 9
# 4
# 4
# 9
# 4
# 4
# 4
# 9
# 9
# 4
# 4
# 4
# 9
# 9
# 9
# 4
# 9
# 4
# 4
# 9
# 9
# 4
# 4
# 4
# 4
# 4
# 9
# 4
# 4
# 9
# 4
# 9
# 4
# 9
# 4
# 9
# 9
# 9
# 4
# 4
# 9
# 4
# 4
# 4
# 9
# 4
# 9
# 9
# 9
# 4
# 9
# 9
# 9
# 4
# 4
# 9
# 4
# 4
# 9
# 9
# 4
# 4
# 9
# 4
# 9
# 4
# 4
# 9
# 4
# 4
# ...

# %%
print(len(indices_each_node_case[4][0]))
print(len(indices_each_node_case[4][1]))
print(len(indices_each_node_case[4][2]))
print(len(indices_each_node_case[4][3]))
print(len(indices_each_node_case[4][4]))

case4_node1_indicies = indices_each_node_case[4][0]
case4_node2_indicies = indices_each_node_case[4][1]
case4_node3_indicies = indices_each_node_case[4][2]
case4_node4_indicies = indices_each_node_case[4][3]
case4_node5_indicies = indices_each_node_case[4][4]
# Out:
# 8762
# 9135
# 5923
# 6180
# 6180

# %%
for element in case4_node5_indicies:
    print(train_label_orig[element])
# Out:
# 3
# 3
# 3
# 7
# 3
# 7
# 3
# 7
# 7
# 3
# 3
# 3
# 7
# 7
# 3
# 7
# 7
# 3
# 7
# 7
# 3
# 7
# 7
# 3
# 3
# 7
# 3
# 3
# 3
# 7
# 7
# 7
# 3
# 3
# 7
# 7
# 3
# 3
# 7
# 7
# 7
# 3
# 3
# 3
# 7
# 7
# 3
# 7
# 3
# 7
# 3
# 3
# 7
# 3
# 3
# 3
# 7
# 7
# 3
# 3
# 7
# 3
# 3
# 7
# 7
# 7
# 3
# 7
# 3
# 3
# 7
# 7
# 3
# 7
# 7
# 3
# 3
# 7
# 7
# 7
# 7
# 7
# 3
# 3
# 7
# 7
# 3
# 7
# 3
# 7
# 7
# 3
# 3
# 7
# 7
# 7
# 3
# 7
# 3
# 3
# 3
# 7
# 3
# 7
# 3
# 7
# 7
# 7
# 7
# 3
# 3
# 3
# 3
# 7
# 3
# 7
# 7
# 3
# 3
# 7
# 7
# 7
# 7
# 3
# 7
# 7
# 3
# 7
# 7
# 7
# 7
# 3
# 7
# 3
# 7
# 7
# 3
# 3
# 3
# 7
# 7
# 3
# 7
# 3
# 7
# 7
# 7
# 7
# 3
# 7
# 3
# 7
# 3
# 3
# 7
# 7
# 3
# 7
# 7
# 7
# 3
# 3
# 7
# 7
# 7
# 7
# 3
# 3
# 7
# 3
# 3
# 3
# 3
# 7
# 3
# 3
# 3
# 7
# 7
# 7
# 7
# 3
# 3
# 7
# 7
# 7
# 3
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 7
# 3
# 7
# 7
# 3
# 7
# 7
# 7
# 3
# 7
# 3
# 3
# 7
# 7
# 3
# 7
# 3
# 7
# 7
# 3
# 7
# 7
# 3
# 7
# 7
# 7
# 3
# 7
# 3
# 7
# 7
# 3
# 7
# 7
# 3
# 7
# 3
# 7
# 3
# 3
# 7
# 7
# 7
# 3
# 3
# 3
# 3
# 3
# 7
# 7
# 7
# 7
# 3
# 7
# 3
# ...
